# %%
import numpy as np
import pandas as pd

# %%
dc = pd.read_csv('credits.csv')
dc
# Out:
#        person_id         id                name                  character  \
# 0           3180    tm82169  Sylvester Stallone      Robert "Rocky" Balboa
# 1           7748    tm82169         Talia Shire  Adrianna "Adrian" Pennino
# 2           7749    tm82169          Burt Young             Paulie Pennino
# 3           7750    tm82169       Carl Weathers               Apollo Creed
# 4           7751    tm82169    Burgess Meredith            Mickey Goldmill
# ...          ...        ...                 ...                        ...
# 81350     449518  tm1072700       Kayode Olaiya                 Uncle Adio
# 81351    2722717  tm1072700         Tolu Osaile                       Sade
# 81352    2722797  tm1072700      Eniola Oyetola               Officer Meks
# 81353     866314  tm1072700         Tope Tedela               Officer Jack
# 81354    1807691  tm1072700      Taiwo Egunjobi                        NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# ...

# %%
df = pd.read_csv('titles.csv')
df
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm82169                                Rocky  MOVIE
# 2       tm17823                               Grease  MOVIE
# 3      tm191099                            The Sting  MOVIE
# 4       tm69975                             Rocky II  MOVIE
# ...         ...                                  ...    ...
# 6132  tm1303784                        عبود في البيت  MOVIE
# 6133  tm1260999                              Sweetie  MOVIE
# 6134  tm1310286            Sommore: Queen Chandelier  MOVIE
# 6135  tm1072700                         All Na Vibes  MOVIE
# 6136   tm561709                      Going to Heaven  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     When world heavyweight boxing champion, Apollo...          1976
# ...

# %%
data = pd.merge(dc,df,on='id')
data.head()
# Out:
#    person_id       id                name                  character   role  \
# 0       3180  tm82169  Sylvester Stallone      Robert "Rocky" Balboa  ACTOR
# 1       7748  tm82169         Talia Shire  Adrianna "Adrian" Pennino  ACTOR
# 2       7749  tm82169          Burt Young             Paulie Pennino  ACTOR
# 3       7750  tm82169       Carl Weathers               Apollo Creed  ACTOR
# 4       7751  tm82169    Burgess Meredith            Mickey Goldmill  ACTOR
#
#    title   type                                        description  \
# 0  Rocky  MOVIE  When world heavyweight boxing champion, Apollo...
# 1  Rocky  MOVIE  When world heavyweight boxing champion, Apollo...
# 2  Rocky  MOVIE  When world heavyweight boxing champion, Apollo...
# 3  Rocky  MOVIE  When world heavyweight boxing champion, Apollo...
# 4  Rocky  MOVIE  When world heavyweight boxing champion, Apollo...
#
#    release_year age_certification  runtime              genres  \
# ...

# %%
data.groupby(by='title')['imdb_score'].mean().sort_values(ascending=False).head(20)
# Out:
# title
# Crazy Delicious                                  9.6
# Breaking Bad                                     9.5
# Our Planet                                       9.3
# The Chosen                                       9.3
# Avatar: The Last Airbender                       9.3
# Reply 1988                                       9.2
# The Last Dance                                   9.1
# My Mister                                        9.1
# Kota Factory                                     9.0
# Okupas                                           9.0
# The Dark Knight                                  9.0
# DEATH NOTE                                       9.0
# Hunter x Hunter                                  9.0
# Attack on Titan                                  9.0
# Arcane                                           9.0
# The Lord of the Rings: The Return of the King    9.0
# David Attenborough: A Life on Our Planet         8.9
# One Piece                                        8.9
# ...
